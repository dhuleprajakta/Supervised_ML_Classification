# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %%
df= pd.read_csv(r"C:\Users\SHRI\OneDrive\Desktop\DataScience_DataFiles\ML_data\Wine.csv")

# %% [markdown]
# # Data Understnding

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
for i in df:
    print(i , ' : ', df[i].unique())
    print('=======================================')
# Out:
# Alcohol  :  [14.23 13.2  13.16 14.37 13.24 14.2  14.39 14.06 14.83 13.86 14.1  14.12
#  13.75 14.75 14.38 13.63 14.3  13.83 14.19 13.64 12.93 13.71 12.85 13.5
#  13.05 13.39 13.3  13.87 14.02 13.73 13.58 13.68 13.76 13.51 13.48 13.28
#  13.07 14.22 13.56 13.41 13.88 14.21 13.9  13.94 13.82 13.77 13.74 13.29
#  13.72 12.37 12.33 12.64 13.67 12.17 13.11 13.34 12.21 12.29 13.49 12.99
#  11.96 11.66 13.03 11.84 12.7  12.   12.72 12.08 12.67 12.16 11.65 11.64
#  12.69 11.62 12.47 11.81 12.6  12.34 11.82 12.51 12.42 12.25 12.22 11.61
#  11.46 12.52 11.76 11.41 11.03 12.77 11.45 11.56 11.87 12.07 12.43 11.79
#  12.04 12.86 12.88 12.81 12.53 12.84 13.36 13.52 13.62 12.87 13.32 13.08
#  12.79 13.23 12.58 13.17 13.84 12.45 14.34 12.36 13.69 12.96 13.78 13.45
#  12.82 13.4  12.2  14.16 13.27 14.13]
# ...
# Malic_Acid  :  [1.71 1.78 2.36 1.95 2.59 1.76 1.87 2.15 1.64 1.35 2.16 1.48 1.73 1.81
#  1.92 1.57 1.59 3.1  1.63 3.8  1.86 1.6  2.05 1.77 1.72 1.9  1.68 1.5
# ...

# %%
df.columns.to_list()
# Out:
# ['Alcohol',
#  'Malic_Acid',
#  'Ash',
#  'Ash_Alcanity',
#  'Magnesium',
#  'Total_Phenols',
#  'Flavanoids',
#  'Nonflavanoid_Phenols',
#  'Proanthocyanins',
#  'Color_Intensity',
#  'Hue',
#  'OD280',
#  'Proline',
#  'Customer_Segment']

# %% [markdown]
# - **All column are given in correct Syntax**
# - **change output variable name Customer_Segment to Quality**

# %%
df = df.rename(columns = {'Customer_Segment' : 'Quality'})

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Quality
# 0   3.92     1065        1
# 1   3.40     1050        1
# ...

# %%
df.dtypes
# Out:
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Ash_Alcanity            float64
# Magnesium                 int64
# Total_Phenols           float64
# Flavanoids              float64
# Nonflavanoid_Phenols    float64
# Proanthocyanins         float64
# Color_Intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                   int64
# Quality                   int64
# dtype: object

# %%
continous = ['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity',  'Magnesium', 'Proline',
       'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
       'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280']

categorical = ['Quality']

# %%
df[continous].skew()
# Out:
# Alcohol                -0.051482
# Malic_Acid              1.039651
# Ash                    -0.176699
# Ash_Alcanity            0.213047
# Magnesium               1.098191
# Proline                 0.767822
# Total_Phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid_Phenols    0.450151
# Proanthocyanins         0.517137
# Color_Intensity         0.868585
# Hue                     0.021091
# OD280                  -0.307285
# dtype: float64

# %% [markdown]
# **All columns are normally distributed**

# %%
j=1
plt.figure(figsize=(25,20))
for i in continous:
    plt.subplot(4,4,j)
    sns.boxplot(df[i])
    plt.title(f'{i}')
    j=j+1
plt.show()

# %% [markdown]
# **Too few outliers that can be negligible**

# %%
j=1
plt.figure(figsize=(25,20))
for i in continous:
    plt.subplot(4,4,j)
    sns.histplot(df[i], bins = 7, kde = True)
    plt.title(f'{i}')
    j=j+1
plt.show()

# %% [markdown]
# **Data is normally distributed**

# %%
df[continous].describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#            Proline  Total_Phenols  Flavanoids  Nonflavanoid_Phenols  \
# count   178.000000     178.000000  178.000000            178.000000
# mean    746.893258       2.295112    2.029270              0.361854
# std     314.907474       0.625851    0.998859              0.124453
# min     278.000000       0.980000    0.340000              0.130000
# ...

# %%
for i in categorical:
    print(i , ' : ', df[i].value_counts())
# Out:
# Quality  :  Quality
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Quality'])
plt.show()

# %% [markdown]
# - **From the count plot, segment 2 has the highest number of occurrences, followed by segment 1 and then segment 3.**
# - This suggests that wines belonging to segment 2 are the most common in this dataset.
# - If this dataset is used for classification, the model might be slightly biased toward predicting segment 2 more often.

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Quality                 0
# dtype: int64

# %% [markdown]
# **No null values**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Dataset not contain duplicates**

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Quality
# 0   3.92     1065        1
# 1   3.40     1050        1
# ...

# %% [markdown]
# # mapping for output variable
#
# **bcoz its starts from 1 but when we devide X and y that y wants data starts from 0**

# %%
df['Quality'] = df['Quality'].map({1: 0, 2: 1, 3: 2})
df['Quality'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df[continous].corr(),annot=True)
plt.show()

# %%
sns.pairplot(df[continous])
plt.show()

# %% [markdown]
# # Save the cleaned data

# %%
df.to_csv('cleaned_dataset_Wine.csv', index=False)
