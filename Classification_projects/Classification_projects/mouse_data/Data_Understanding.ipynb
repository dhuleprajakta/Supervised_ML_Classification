# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Business Problem
#
# - The data shown here simulates a medical study in which mice infected with a virus were given various doses of two medicines and then checked 2 weeks later to see if they were stll infected
#
# **Goal is to create a classification model than predict (Give two doses measurements) if they mouse will still be infected with the virus**

# %%
df = pd.read_csv(r"C:\Users\SHRI\OneDrive\Desktop\DataScience_DataFiles\ML_data\mouse_viral_study.csv")

# %% [markdown]
# # Data Undersatnding

# %%
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
df.shape
# Out:
# (400, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Med_1_mL       400 non-null    float64
#  1   Med_2_mL       400 non-null    float64
#  2   Virus Present  400 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 9.5 KB

# %% [markdown]
# **Observation**
# - no null values present
# - all datatypes are correct
# - output variable is 'Virus Present' is not in correct syntax remov the space between name

# %%
df.columns.tolist()
# Out:
# ['Med_1_mL', 'Med_2_mL', 'Virus Present']

# %%
df = df.rename(columns = {"Virus Present" : 'Virus_Present'})

# %%
df
# Out:
#      Med_1_mL  Med_2_mL  Virus_Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
continous = ['Med_1_mL', 'Med_2_mL']
count = ['Virus_Present']

# %%
df[continous].skew()
# Out:
# Med_1_mL   -0.011422
# Med_2_mL    0.004315
# dtype: float64

# %% [markdown]
# **Observation**
# - all columns are normally distributed
#
# # visualization of continous

# %%
for i in continous:
    sns.histplot(df[i], bins = 7, kde = True)
    plt.show()

# %%
for i in continous:
    sns.boxplot(df[i])
    plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# **Observation**
# -No outliers present
#
#
# **Data is clean now use for classification**

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Med_1_mL         0
# Med_2_mL         0
# Virus_Present    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# NO duplicates values

# %%
# no need of preprocessing
# no need of data wrangling

# %% [markdown]
# # Save the clean data

# %%
df.to_csv('cleaned_dataset_mouse.csv', index=False)
